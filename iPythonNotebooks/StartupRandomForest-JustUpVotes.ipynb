# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import feature_extraction

# Borrowed from: http://nbviewer.ipython.org/github/gmonce/scikit-learn-book/tree/master/ (Chapter 4)
def one_hot_dataframe(data, cols, replace=False):
    """ Takes a dataframe and a list of columns that need to be encoded.
    Returns a 3-tuple comprising the data, the vectorized data,
    and the fitted vectorizor.
    Modified from https://gist.github.com/kljensen/5452382
    """
    vec = feature_extraction.DictVectorizer()
    mkdict = lambda row: dict((col, row[col]) for col in cols)

    vecData = pd.DataFrame(vec.fit_transform(data[cols].to_dict(outtype='records')).toarray())
    vecData.columns = vec.get_feature_names()
    vecData.index = data.index
    if replace is True:
        data = data.drop(cols, axis=1)
        data = data.join(vecData)
    return (data, vecData)

# %%
# Load HackerNews data.
hacerknewsdata = pd.DataFrame()
hackernewsdata = pd.read_csv('../Datasets/HNTitleCommentsSentimentData.csv')
hackernewsdata = hackernewsdata.drop(['Unnamed: 0'], 1)

# %%
# Load YC startups data.
cleanstartups = pd.DataFrame()
cleanstartups = pd.read_csv('../Datasets/CleanStartupsFull.csv')
cleanstartups = cleanstartups.drop(['Unnamed: 0'], 1)

# %%
# Merge the cleaned-up YC startup data with Hacker News data.
fullset = pd.merge(hackernewsdata, cleanstartups, on='Company', how='inner')

# %%
# Going to convert those that have exited YC as remaining in operation.
# I want to keep the perdiction simple: in operation or dead.
# I will think of ways to incorporate startups that have exited as a classifer after my demo.
fullset.Fate[fullset.Fate != 'Dead'] = 'Operating'

# %%
# To create training set, first separate startups that are not operating versus those that remain in operation.
# Because there aren't as many dead startups, I will only use an equal amount of active startups (chosen by random). 
deadset = fullset.TitlePoints[fullset.Fate == 'Dead']
operatingset = fullset[fullset.Fate == 'Operating']
rows = np.random.choice(operatingset.index.values, len(deadset))
operatingset = operatingset.ix[rows]

# Now merge together the dead and operating startups -- this will be the training set for now.
trainingset = deadset.append(operatingset)

# %%
trainingset
# Out:
#        0           City           Company  \
# 34     7            NaN               NaN
# 37    71            NaN               NaN
# 49    94            NaN               NaN
# 70    80            NaN               NaN
# 80   227            NaN               NaN
# 87    30            NaN               NaN
# 139   71            NaN               NaN
# 146   77            NaN               NaN
# 161   21            NaN               NaN
# 199   51            NaN               NaN
# 205   87            NaN               NaN
# 210   31            NaN               NaN
# 221   43            NaN               NaN
# 226  118            NaN               NaN
# 249  198            NaN               NaN
# 254   92            NaN               NaN
# 255   13            NaN               NaN
# 268  171            NaN               NaN
# 274    9            NaN               NaN
# 277   16            NaN               NaN
# 288    6            NaN               NaN
# 292   87            NaN               NaN
# 293   86            NaN               NaN
# 294   60            NaN               NaN
# 297   49            NaN               NaN
# 298   76            NaN               NaN
# 306   18            NaN               NaN
# 307    3            NaN               NaN
# 309    2            NaN               NaN
# 314   90            NaN               NaN
# ..   ...            ...               ...
# 398  NaN  San Francisco         Simperium
# 134  NaN  San Francisco            Heroku
# 8    NaN  San Francisco            Movity
# 203  NaN  San Francisco           AirHelp
# 408  NaN  Mountain View         SpinPunch
# 358  NaN  Mountain View           Parakey
# 214  NaN  San Francisco         Bannerman
# 279  NaN            NaN        Gbatteries
# 355  NaN            NaN              Opez
# 23   NaN  San Francisco         PagerDuty
# 350  NaN            NaN          Newsblur
# 69   NaN      Palo Alto            Gobble
# 419  NaN  Mountain View           TalkBin
# 82   NaN  New York City          Lawdingo
# 484  NaN            NaN          WeFunder
# 448  NaN  San Francisco           Userfox
# 371  NaN            NaN    PollEverywhere
# 447  NaN         Boston            UPower
# 190  NaN  New York City        Codecademy
# 331  NaN  Mountain View       MarketBrief
# 445  NaN  San Francisco            uBiome
# 128  NaN      Palo Alto  Science Exchange
# 389  NaN  Mountain View        Semantics3
# 437  NaN      Sunnyvale            Tiempo
# 204  NaN  San Francisco           AirPair
# 30   NaN         London        GoCardless
# 286  NaN  San Francisco       Hackermeter
# 50   NaN  San Francisco        Tastemaker
# 185  NaN  San Francisco           SwapBox
# 330  NaN            NaN   MakeGamesWithUs
#
#                             CrunchBaseAngelListProfile  \
# 34                                                 NaN
# 37                                                 NaN
# 49                                                 NaN
# 70                                                 NaN
# 80                                                 NaN
# 87                                                 NaN
# 139                                                NaN
# 146                                                NaN
# 161                                                NaN
# 199                                                NaN
# 205                                                NaN
# 210                                                NaN
# 221                                                NaN
# 226                                                NaN
# 249                                                NaN
# 254                                                NaN
# 255                                                NaN
# 268                                                NaN
# 274                                                NaN
# 277                                                NaN
# 288                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 297                                                NaN
# 298                                                NaN
# 306                                                NaN
# 307                                                NaN
# 309                                                NaN
# 314                                                NaN
# ..                                                 ...
# 398   http://www.crunchbase.com/organization/simperium
# 134      http://www.crunchbase.com/organization/heroku
# 8    http://www.crunchbase.com/organization/movity-com
# 203     http://www.crunchbase.com/organization/airhelp
# 408   http://www.crunchbase.com/organization/spinpunch
# 358     http://www.crunchbase.com/organization/parakey
# 214   http://www.crunchbase.com/organization/bannerman
# 279  http://www.crunchbase.com/organization/gbatteries
# 355        http://www.crunchbase.com/organization/opez
# 23    http://www.crunchbase.com/organization/pagerduty
# 350    http://www.crunchbase.com/organization/newsblur
# 69       http://www.crunchbase.com/organization/gobble
# 419     http://www.crunchbase.com/organization/talkbin
# 82     http://www.crunchbase.com/organization/lawdingo
# 484    http://www.crunchbase.com/organization/wefunder
# 448     http://www.crunchbase.com/organization/userfox
# 371  http://www.crunchbase.com/organization/polleve...
# 447      http://www.crunchbase.com/organization/upower
# 190  http://www.crunchbase.com/organization/codecademy
# 331  http://www.crunchbase.com/organization/marketb...
# 445      http://www.crunchbase.com/organization/ubiome
# 128  http://www.crunchbase.com/organization/science...
# 389  http://www.crunchbase.com/organization/semantics3
# 437    http://www.crunchbase.com/organization/tiempo-2
# 204     http://www.crunchbase.com/organization/airpair
# 30   http://www.crunchbase.com/organization/gocardless
# 286  http://www.crunchbase.com/organization/hackerm...
# 50   http://www.crunchbase.com/organization/tastemaker
# 185     http://www.crunchbase.com/organization/swapbox
# 330  http://www.crunchbase.com/organization/makegam...
#
#                                            Description       Fate  \
# 34                                                 NaN        NaN
# 37                                                 NaN        NaN
# 49                                                 NaN        NaN
# 70                                                 NaN        NaN
# 80                                                 NaN        NaN
# 87                                                 NaN        NaN
# 139                                                NaN        NaN
# 146                                                NaN        NaN
# 161                                                NaN        NaN
# 199                                                NaN        NaN
# 205                                                NaN        NaN
# 210                                                NaN        NaN
# 221                                                NaN        NaN
# 226                                                NaN        NaN
# 249                                                NaN        NaN
# 254                                                NaN        NaN
# 255                                                NaN        NaN
# 268                                                NaN        NaN
# 274                                                NaN        NaN
# 277                                                NaN        NaN
# 288                                                NaN        NaN
# 292                                                NaN        NaN
# 293                                                NaN        NaN
# 294                                                NaN        NaN
# 297                                                NaN        NaN
# 298                                                NaN        NaN
# 306                                                NaN        NaN
# 307                                                NaN        NaN
# 309                                                NaN        NaN
# 314                                                NaN        NaN
# ..                                                 ...        ...
# 398  Simperium offers a platform for syncing conten...  Operating
# 134  Heroku is a cloud-based platform-as-a-service ...  Operating
# 8    Movity is a website providing location-based l...  Operating
# 203   Get money when the airlines screw up your flight  Operating
# 408  SpinPunch develops browser-based real-time str...  Operating
# 358  Parakey is a web-based operating system that s...  Operating
# 214                         On Demand Private Security  Operating
# 279                            Portable backup battery  Operating
# 355  Opez is dedicated to helping you discover exce...  Operating
# 23   PagerDuty is an operations performance platfor...  Operating
# 350  NewsBlur is a personal news reader that brings...  Operating
# 69   Gobble is an online marketplace for authentic ...  Operating
# 419  TalkBin offers a tool that allows customers to...  Operating
# 82   Lawdingo helps people connect with attorneys f...  Operating
# 484  Wefunder is a crowd investing platform that of...  Operating
# 448  userfox is an email services platform helping ...  Operating
# 371  Our mission is to make real time presentations...  Operating
# 447  UPower technology enables an always on contain...  Operating
# 190  Codecademy is a free web- and mobile-based pla...  Operating
# 331  MarketBrief analyzes 30000+ trusted documents ...  Operating
# 445  uBiome gives you access to cutting edge DNA se...  Operating
# 128  Science Exchange is a marketplace for scientif...  Operating
# 389            Largest database of products and prices  Operating
# 437        The fastest way to track time and get paid.  Operating
# 204                        Tech Expertise At Your Side  Operating
# 30   GoCardless is a UK-based online direct debit p...  Operating
# 286                        Hiring with code portfolios  Operating
# 50   Tastemaker is an online hub connecting home an...  Operating
# 185  Swapbox provides shipping services for online ...  Operating
# 330  MakeGamesWithUs is an iOS game publisher that ...  Operating
#
#                                               Founders             Founders1  \
# 34                                                 NaN                   NaN
# 37                                                 NaN                   NaN
# 49                                                 NaN                   NaN
# 70                                                 NaN                   NaN
# 80                                                 NaN                   NaN
# 87                                                 NaN                   NaN
# 139                                                NaN                   NaN
# 146                                                NaN                   NaN
# 161                                                NaN                   NaN
# 199                                                NaN                   NaN
# 205                                                NaN                   NaN
# 210                                                NaN                   NaN
# 221                                                NaN                   NaN
# 226                                                NaN                   NaN
# 249                                                NaN                   NaN
# 254                                                NaN                   NaN
# 255                                                NaN                   NaN
# 268                                                NaN                   NaN
# 274                                                NaN                   NaN
# 277                                                NaN                   NaN
# 288                                                NaN                   NaN
# 292                                                NaN                   NaN
# 293                                                NaN                   NaN
# 294                                                NaN                   NaN
# 297                                                NaN                   NaN
# 298                                                NaN                   NaN
# 306                                                NaN                   NaN
# 307                                                NaN                   NaN
# 309                                                NaN                   NaN
# 314                                                NaN                   NaN
# ..                                                 ...                   ...
# 398        Fred Cheng, Michael Johnston, Mike Johnston            Fred Cheng
# 134                     Adam Wiggins, James Lindenbaum          Adam Wiggins
# 8                      Eric Wu, Sha Hwang, Vaughn Koch               Eric Wu
# 203                                                NaN                   NaN
# 408                                           Ian Tien              Ian Tien
# 358                             Blake Ross, Joe Hewitt            Blake Ross
# 214                                                NaN                   NaN
# 279                                                NaN                   NaN
# 355                                                NaN                   NaN
# 23    Alex Solomon, Andrew Miklas, Baskar Puvanathasan          Alex Solomon
# 350                                                NaN                   NaN
# 69                                         Ooshma Garg           Ooshma Garg
# 419                           Michael Ma, Qasar Younis            Michael Ma
# 82                                       Nikhil Nirmel         Nikhil Nirmel
# 484          Greg Belote, Mike Norman, Nick Tommarello           Greg Belote
# 448                          Cesar Alaniz, Peter Clark          Cesar Alaniz
# 371                                                NaN                   NaN
# 447                                                NaN                   NaN
# 190                           Ryan Bubinski, Zach Sims         Ryan Bubinski
# 331       Chris Auer, Jason Zucchetto, Michael Shafrir            Chris Auer
# 445                      Jessica Richman, Zachary Apte       Jessica Richman
# 128             Dan Knox, Elizabeth Iorns, Ryan Abbott              Dan Knox
# 389  Govind Chandrasekhar, Sivamani Varun, Vinoth G...  Govind Chandrasekhar
# 437            Kyle Kilat, Peter Terrill, Tad Milbourn            Kyle Kilat
# 204       Igor Lebovic, Jonathon Kresner, Maksim Ioffe          Igor Lebovic
# 30                      Hiroki Takeuchi, Matt Robinson       Hiroki Takeuchi
# 286                                           Frost Li              Frost Li
# 50   Esther Park, Joe Fraiman, Juan Vasquez, Kyle L...           Esther Park
# 185                      Neel Murthy, Nitin Shantharam           Neel Murthy
# 330                                                NaN                   NaN
#
#             Founders2            Founders3         ...           \
# 34                NaN                  NaN         ...
# 37                NaN                  NaN         ...
# 49                NaN                  NaN         ...
# 70                NaN                  NaN         ...
# 80                NaN                  NaN         ...
# 87                NaN                  NaN         ...
# 139               NaN                  NaN         ...
# 146               NaN                  NaN         ...
# 161               NaN                  NaN         ...
# 199               NaN                  NaN         ...
# 205               NaN                  NaN         ...
# 210               NaN                  NaN         ...
# 221               NaN                  NaN         ...
# 226               NaN                  NaN         ...
# 249               NaN                  NaN         ...
# 254               NaN                  NaN         ...
# 255               NaN                  NaN         ...
# 268               NaN                  NaN         ...
# 274               NaN                  NaN         ...
# 277               NaN                  NaN         ...
# 288               NaN                  NaN         ...
# 292               NaN                  NaN         ...
# 293               NaN                  NaN         ...
# 294               NaN                  NaN         ...
# 297               NaN                  NaN         ...
# 298               NaN                  NaN         ...
# 306               NaN                  NaN         ...
# 307               NaN                  NaN         ...
# 309               NaN                  NaN         ...
# 314               NaN                  NaN         ...
# ..                ...                  ...         ...
# 398  Michael Johnston        Mike Johnston         ...
# 134  James Lindenbaum                  NaN         ...
# 8           Sha Hwang          Vaughn Koch         ...
# 203               NaN                  NaN         ...
# 408               NaN                  NaN         ...
# 358        Joe Hewitt                  NaN         ...
# 214               NaN                  NaN         ...
# 279               NaN                  NaN         ...
# 355               NaN                  NaN         ...
# 23      Andrew Miklas  Baskar Puvanathasan         ...
# 350               NaN                  NaN         ...
# 69                NaN                  NaN         ...
# 419      Qasar Younis                  NaN         ...
# 82                NaN                  NaN         ...
# 484       Mike Norman      Nick Tommarello         ...
# 448       Peter Clark                  NaN         ...
# 371               NaN                  NaN         ...
# 447               NaN                  NaN         ...
# 190         Zach Sims                  NaN         ...
# 331   Jason Zucchetto      Michael Shafrir         ...
# 445      Zachary Apte                  NaN         ...
# 128   Elizabeth Iorns          Ryan Abbott         ...
# 389    Sivamani Varun    Vinoth Gopinathan         ...
# 437     Peter Terrill         Tad Milbourn         ...
# 204  Jonathon Kresner         Maksim Ioffe         ...
# 30      Matt Robinson                  NaN         ...
# 286               NaN                  NaN         ...
# 50        Joe Fraiman         Juan Vasquez         ...
# 185  Nitin Shantharam                  NaN         ...
# 330               NaN                  NaN         ...
#
#                                SeedDBMattermarkProfile Sentiment  \
# 34                                                 NaN       NaN
# 37                                                 NaN       NaN
# 49                                                 NaN       NaN
# 70                                                 NaN       NaN
# 80                                                 NaN       NaN
# 87                                                 NaN       NaN
# 139                                                NaN       NaN
# 146                                                NaN       NaN
# 161                                                NaN       NaN
# 199                                                NaN       NaN
# 205                                                NaN       NaN
# 210                                                NaN       NaN
# 221                                                NaN       NaN
# 226                                                NaN       NaN
# 249                                                NaN       NaN
# 254                                                NaN       NaN
# 255                                                NaN       NaN
# 268                                                NaN       NaN
# 274                                                NaN       NaN
# 277                                                NaN       NaN
# 288                                                NaN       NaN
# 292                                                NaN       NaN
# 293                                                NaN       NaN
# 294                                                NaN       NaN
# 297                                                NaN       NaN
# 298                                                NaN       NaN
# 306                                                NaN       NaN
# 307                                                NaN       NaN
# 309                                                NaN       NaN
# 314                                                NaN       NaN
# ..                                                 ...       ...
# 398  http://www.seed-db.com/companies/view?companyi...  2.250000
# 134  http://www.seed-db.com/companies/view?companyi...  1.000000
# 8    http://www.seed-db.com/companies/view?companyi... -0.666667
# 203  http://www.seed-db.com/companies/view?companyi... -1.000000
# 408  http://www.seed-db.com/companies/view?companyi...  0.000000
# 358  http://www.seed-db.com/companies/view?companyi...  1.000000
# 214  http://www.seed-db.com/companies/view?companyi... -0.200000
# 279  http://www.seed-db.com/companies/view?companyi...  0.000000
# 355  http://www.seed-db.com/companies/view?companyi... -3.000000
# 23   http://www.seed-db.com/companies/view?companyi...  0.555556
# 350  http://www.seed-db.com/companies/view?companyi...  3.000000
# 69   http://www.seed-db.com/companies/view?companyi...  0.300000
# 419  http://www.seed-db.com/companies/view?companyi... -0.250000
# 82   http://www.seed-db.com/companies/view?companyi...  0.000000
# 484  http://www.seed-db.com/companies/view?companyi...  3.250000
# 448  http://www.seed-db.com/companies/view?companyi...  1.444444
# 371  http://www.seed-db.com/companies/view?companyi...  0.000000
# 447  http://www.seed-db.com/companies/view?companyi...  0.857143
# 190  http://www.seed-db.com/companies/view?companyi...  1.000000
# 331  http://www.seed-db.com/companies/view?companyi...  1.200000
# 445  http://www.seed-db.com/companies/view?companyi...  2.000000
# 128  http://www.seed-db.com/companies/view?companyi...  1.666667
# 389  http://www.seed-db.com/companies/view?companyi... -0.250000
# 437  http://www.seed-db.com/companies/view?companyi...  0.375000
# 204  http://www.seed-db.com/companies/view?companyi... -2.000000
# 30   http://www.seed-db.com/companies/view?companyi...  2.000000
# 286  http://www.seed-db.com/companies/view?companyi...  0.666667
# 50   http://www.seed-db.com/companies/view?companyi...  0.200000
# 185  http://www.seed-db.com/companies/view?companyi...  0.750000
# 330  http://www.seed-db.com/companies/view?companyi...  1.000000
#
#                                                  Title TitlePoints  \
# 34                                                 NaN         NaN
# 37                                                 NaN         NaN
# 49                                                 NaN         NaN
# 70                                                 NaN         NaN
# 80                                                 NaN         NaN
# 87                                                 NaN         NaN
# 139                                                NaN         NaN
# 146                                                NaN         NaN
# 161                                                NaN         NaN
# 199                                                NaN         NaN
# 205                                                NaN         NaN
# 210                                                NaN         NaN
# 221                                                NaN         NaN
# 226                                                NaN         NaN
# 249                                                NaN         NaN
# 254                                                NaN         NaN
# 255                                                NaN         NaN
# 268                                                NaN         NaN
# 274                                                NaN         NaN
# 277                                                NaN         NaN
# 288                                                NaN         NaN
# 292                                                NaN         NaN
# 293                                                NaN         NaN
# 294                                                NaN         NaN
# 297                                                NaN         NaN
# 298                                                NaN         NaN
# 306                                                NaN         NaN
# 307                                                NaN         NaN
# 309                                                NaN         NaN
# 314                                                NaN         NaN
# ..                                                 ...         ...
# 398  Automattic Buys Simperium (YC S10), Maker of S...          59
# 134             AppHarbor (YC W11): "Azure Done Right"         153
# 8    Noise Visualization in the Tenderloin by Movit...          87
# 203  When Airlines Screw Up Your Flight, AirHelp (Y...         158
# 408  SpinPunch (YC S12) Aims To Build Faster, Prett...          36
# 358  Facebook acquires Blake Ross and Joe Hewitt's ...          32
# 214     Bannerman (YC S14) Delivers Bouncers On Demand          87
# 279  Gbatteries (YC W14) Launches BatteryBox, A 50W...         244
# 355  Opez (YC S11) Is Yelp Meets Facebook, For Serv...         102
# 23   PagerDuty (YC S10) Makes Sure Your Team Knows ...          93
# 350  NewsBlur (YC S12) Takes Feed Reading Back To I...         124
# 69   Gobble (YC W14) Automates Your Dinner With A S...          50
# 419                   Google acquires TalkBin (YC W11)         127
# 82   Lawdingo (YC W13) Raises $690K More To Help Yo...          57
# 484              Wefunder (YC W13): Invest in Startups         136
# 448  Show HN: Userfox (YC S11)  Better Welcome Emails           95
# 371  Show HN: The polleverywhere.com job post annoy...           4
# 447      UPower (YC S14) Is Building Nuclear Batteries         188
# 190  Codecademy (YC S11) Raises $2.5 Million To Tea...         127
# 331  MarketBrief (YC S11) Makes Obtuse SEC Document...         175
# 445  UBiome (YC S14) Raises $4.5M to Crowdsource Mi...          26
# 128  Science Exchange (YC S11) Raises $3M in Series...          47
# 389  Semantics3 (YC W13) Is A Massive Consumer Prod...          79
# 437  Show HN: Tiempo – The fastest way to track tim...         116
# 204  How We Bootstrapped AirPair to Ramen Profitabi...          37
# 30   GoCardless (YC S11) Launches PayLinks, A Bitly...          74
# 286            Pinterest Acquires Hackermeter (YC S13)          56
# 50   Tastemaker (YC S12) is an online interior deco...          72
# 185  Swapbox (YC W13) Launches And Aims To Pick Up ...          35
# 330  MakeGamesWithUs (YC W12) Wants To Turn High Sc...          90
#
#                                             TopComment TopCommentPoints  \
# 34                                                 NaN              NaN
# 37                                                 NaN              NaN
# 49                                                 NaN              NaN
# 70                                                 NaN              NaN
# 80                                                 NaN              NaN
# 87                                                 NaN              NaN
# 139                                                NaN              NaN
# 146                                                NaN              NaN
# 161                                                NaN              NaN
# 199                                                NaN              NaN
# 205                                                NaN              NaN
# 210                                                NaN              NaN
# 221                                                NaN              NaN
# 226                                                NaN              NaN
# 249                                                NaN              NaN
# 254                                                NaN              NaN
# 255                                                NaN              NaN
# 268                                                NaN              NaN
# 274                                                NaN              NaN
# 277                                                NaN              NaN
# 288                                                NaN              NaN
# 292                                                NaN              NaN
# 293                                                NaN              NaN
# 294                                                NaN              NaN
# 297                                                NaN              NaN
# 298                                                NaN              NaN
# 306                                                NaN              NaN
# 307                                                NaN              NaN
# 309                                                NaN              NaN
# 314                                                NaN              NaN
# ..                                                 ...              ...
# 398  Very good. I brought a project to Automattic a...                7
# 134  As a fan of Heroku and Git I love seeing this ...               25
# 8    We try to be inconspicuous when installing our...               13
# 203  My wife and I had our flight from Europe to Ja...               17
# 408  wanted to try the demo game. don't have/want a...                4
# 358  Thanks for the well wishes, guys! Today was ou...               11
# 214  We hired a bannerman guard for a party in down...               13
# 279  Here is a classic example of a startup launchi...               69
# 355  I hate this title. Does "Yelp meets Facebook" ...               17
# 23   I agree. That's why we don't do uptime monitor...               19
# 350  Thrilled to be launching NewsBlur's social fea...               16
# 69   Throwaway account, these things have been shar...               25
# 419  Actually from what I've heard that's not the c...               35
# 82        Starting point: Lawdingo isn't Rocketlawyer.               15
# 484  Wow, that's funny.  As I was reading that, I w...               41
# 448  we built a lot of stuff for userfox over the p...                5
# 371  You can open them another one: it’s “Xcode”, n...                2
# 447  I am one of the UPower founders.  The key take...               31
# 190  I think you mean computer programming here, wh...               15
# 331  This is one of those opportunities that seems ...               12
# 445  Isn't there a close relationship between the h...                2
# 128  thanks (from a Science Exchange founder)! we a...                5
# 389  Yes, this is a big problem, which we have put ...                6
# 437  This looks like a fine product and kudos to it...                9
# 204  Just lettin ya know -- you have a typo in your...                4
# 30   Looks a lot like https://gumroad.com to me, bu...               12
# 286  What a mean-spirited thing to say, and to upvo...               24
# 50   2 years ago I remodeled my house and, for the ...                8
# 185  Some financial thoughts:Machine operating at f...                3
# 330  American culture is quick to dismiss the abili...                9
#
#     TotalFunds                        Website YCSession YCYear
# 34         NaN                            NaN       NaN    NaN
# 37         NaN                            NaN       NaN    NaN
# 49         NaN                            NaN       NaN    NaN
# 70         NaN                            NaN       NaN    NaN
# 80         NaN                            NaN       NaN    NaN
# 87         NaN                            NaN       NaN    NaN
# 139        NaN                            NaN       NaN    NaN
# 146        NaN                            NaN       NaN    NaN
# 161        NaN                            NaN       NaN    NaN
# 199        NaN                            NaN       NaN    NaN
# 205        NaN                            NaN       NaN    NaN
# 210        NaN                            NaN       NaN    NaN
# 221        NaN                            NaN       NaN    NaN
# 226        NaN                            NaN       NaN    NaN
# 249        NaN                            NaN       NaN    NaN
# 254        NaN                            NaN       NaN    NaN
# 255        NaN                            NaN       NaN    NaN
# 268        NaN                            NaN       NaN    NaN
# 274        NaN                            NaN       NaN    NaN
# 277        NaN                            NaN       NaN    NaN
# 288        NaN                            NaN       NaN    NaN
# 292        NaN                            NaN       NaN    NaN
# 293        NaN                            NaN       NaN    NaN
# 294        NaN                            NaN       NaN    NaN
# 297        NaN                            NaN       NaN    NaN
# 298        NaN                            NaN       NaN    NaN
# 306        NaN                            NaN       NaN    NaN
# 307        NaN                            NaN       NaN    NaN
# 309        NaN                            NaN       NaN    NaN
# 314        NaN                            NaN       NaN    NaN
# ..         ...                            ...       ...    ...
# 398          0       http://www.simperium.com    Summer   2010
# 134   13020000          http://www.heroku.com    Winter   2008
# 8      1300000          http://www.movity.com    Winter   2010
# 203        NaN      http://www.getairhelp.com    Winter   2014
# 408          0       http://www.spinpunch.com    Summer   2012
# 358          0         http://www.parakey.com    Winter   2007
# 214     120000        http://getbannerman.com    Summer   2014
# 279        NaN      http://www.gbatteries.com    Winter   2014
# 355          0            http://www.opez.com    Summer   2011
# 23    39800000       http://www.pagerduty.com    Summer   2010
# 350          0            http://newsblur.com    Summer   2012
# 69     1200000              http://gobble.com    Winter   2014
# 419          0         http://www.talkbin.com    Winter   2011
# 82      790000        http://www.lawdingo.com    Winter   2013
# 484     530000        http://www.wefunder.com    Winter   2013
# 448     700000         http://www.userfox.com    Summer   2011
# 371          0  http://www.polleverywhere.com    Summer   2008
# 447     170000      http://www.upowertech.com    Summer   2014
# 190   12500000      http://www.codecademy.com    Summer   2011
# 331          0         http://marketbrief.com    Summer   2011
# 445    4620351              http://ubiome.com    Summer   2014
# 128    5500000     http://scienceexchange.com    Summer   2011
# 389          0      http://www.semantics3.com    Winter   2013
# 437     120000      http://www.tiempoapp.com/    Summer   2014
# 204          0         http://www.airpair.com    Winter   2014
# 30    11800000          http://gocardless.com    Summer   2011
# 286          0     http://www.hackermeter.com    Summer   2013
# 50     2900000      http://www.tastemaker.com    Summer   2012
# 185     800000             http://swapbox.com    Winter   2013
# 330          0    http://www.makegameswith.us    Winter   2012
#
# [132 rows x 33 columns]

# %%
# Truncating full set to exclude features that aren't going to be in the decision tree.
trainingset = trainingset.drop(['Company','Title','TopComment','TopCommentPoints','Fate','Description','Logo',
                    'SeedDBMattermarkProfile','CrunchBaseAngelListProfile','Website',
                    'YCYear','YCSession','Market','Founders','Investors','TitlePoints'], 1)

# Also have to deal with missing values and data types.
trainingset[['Sentiment','TotalFunds']] = trainingset[['Sentiment','TotalFunds']].fillna(0.0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-64dd9f4f39db> in <module>()
#       1 # Truncating full set to exclude features that aren't going to be in the decision tree.
# ----> 2 trainingset = trainingset.TitlePoints
#       3
#       4 # Also have to deal with missing values and data types.
#       5 trainingset[['Sentiment','TotalFunds']] = trainingset[['Sentiment','TotalFunds']].fillna(0.0).astype(int)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'TitlePoints'

# %%
testset = pd.DataFrame(fullset.Fate[trainingset.index])

# %%
from sklearn.preprocessing import label_binarize
# Transforming lists of feature-value mappings to vectors.
# This also transforms and encodes categorical integer features using a variation of one-hot scheme.
trainingset, trainingset_n = one_hot_dataframe(trainingset, ['City', 'Investors1', 'Investors2', 'Investors3', 'Investors4',
                                                             'Founders1', 'Founders2', 'Founders3', 'Founders4',
                                                             'Market1', 'Market2', 'Market3', 'Market4', 
                                                             'Market5'], replace=True)
trainingset = trainingset.fillna(0)

testset, testset_n = one_hot_dataframe(testset, ['Fate'], replace=True)
testset = testset.fillna(0)

# %%
# Binarize the output
testset = label_binarize(testset, classes=[0, 1])
n_classes = testset.shape[1]

# %%
from sklearn import cross_validation
X_train, X_test, y_train, y_test = cross_validation.train_test_split(trainingset, 
                                                                     testset, 
                                                                     test_size=0.4)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=30,
                             criterion="entropy", 
                             max_features="auto",
                             bootstrap=True, 
                             n_jobs=8, 
                             random_state=1)
clf = clf.fit(X_train, y_train)

# %%
preds = clf.predict_proba(X_test)[:][1]
clf.score(X_test, y_test)
# Out:
# 0.7142857142857143

# %%
from sklearn.metrics import roc_curve, auc

font = {'family' : 'Arial',
        'size'   : 20}

plt.rc('font', **font)

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), preds.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot of a ROC curve for a specific class
plt.figure(figsize=(10, 7.5), dpi=600)
plt.plot(fpr[1], tpr[1], label='ROC Curve (area = %0.2f)' % roc_auc[1], linewidth=3)
plt.plot([0, 1], [0, 1], 'k--', linewidth=3)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.savefig('Figures/ROCCurve.png')
plt.show()

# Plot ROC curve
plt.figure(figsize=(10, 7.5), dpi=600)
plt.plot(fpr["micro"], tpr["micro"],
         label='Micro-Average ROC Curve', linewidth=3)
for i in range(2):
    if i == 0:
        plt.plot(fpr[i], tpr[i], label='ROC Curve - Not Operating', linewidth=3)
    else:
        plt.plot(fpr[i], tpr[i], label='ROC Curve - Operating', linewidth=3)
plt.plot([0, 1], [0, 1], 'k--', linewidth=3)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic to Multi-Class')
plt.legend(loc="lower right")
plt.savefig('Figures/ROCCurveMultiClass.png')
plt.show()

# %%
import pickle
pickle.dump( clf, open( "Datasets/RandomForestStartup.p", "wb" ) )

# %%
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier

importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(10):
    print("%d. %s (%f)" % (f + 1, trainingset.columns[indices][f], importances[indices[f]]))

# Plot the feature importances of the forest
figure(figsize=(10, 7.5), dpi=600)
barh(range(10), importances[indices][:10], color="orange", align="center")
yticks(range(10), trainingset.columns[indices][:10])
plt.ylim([-1,10])
plt.gca().invert_yaxis()
title("Feature Importances")
plt.savefig('Figures/FeatureImportance.png')
plt.show()

# %%
# Going to clean up the fullset of data to run in random tree classifier.
fullsetbackup = fullset
fullsetbackup = fullsetbackup.drop(['Company','Title','TopComment','Fate','Description','Logo','SeedDBMattermarkProfile', 
                              'CrunchBaseAngelListProfile', 'Website', 'YCYear', 'YCSession',
                              'Market','Founders','Investors'], 1)
fullsetbackup[['Sentiment','TotalFunds']] = fullsetbackup[['Sentiment','TotalFunds']].fillna(0.0).astype(int)
fullsetbackup, fullsetbackup_n = one_hot_dataframe(fullsetbackup, ['City', 'Investors1', 'Investors2', 
                                                                   'Investors3', 'Investors4', 'Founders1', 'Founders2', 
                                                                   'Founders3', 'Founders4','Market1', 'Market2', 'Market3', 
                                                                   'Market4', 'Market5'], replace=True)
fullsetbackup = fullsetbackup.fillna(0)
fullsetbackup = fullsetbackup[trainingset.columns]

# %%
classifier = []
probs = []
for index, row in fullsetbackup.iterrows():
    predictedfate = clf.predict(row)
    if predictedfate[0][0] > 0:
        classifier.append('Not Operating')
        probs.append(clf.predict_proba(row)[0][0][1])
    else:
        classifier.append('Operating')
        probs.append(clf.predict_proba(row)[1][0][1])

# %%
fullset['Prediction'] = classifier
fullset['Probability'] = probs

# %%
# plotdata = pd.DataFrame(columns=['nTrees','Scores'])
# plotdata.nTrees = ntrees
# plotdata.Scores = scores

# %%
# chartdata = pd.DataFrame(columns=['Features','FeatureValues'])
# chartdata.Features = trainingset.columns[indices][:10]
# chartdata.FeatureValues = importances[indices][:10]

# %%
# plotdata.to_csv('PlotData.csv', sep=',', encoding='utf-8')
# chartdata.to_csv('ChartData.csv', sep=',', encoding='utf-8')

# %%
# import pickle
# clf = pickle.load( open( "randomforeststartup.p", "rb" ) )

# %%
# Backing up fullset, now with predicted classifier.
fullset.to_csv('Datasets/CompleteSet.csv', sep=',', encoding='utf-8')
